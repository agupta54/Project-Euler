# %%
n = ...
m = 13

L = [int(i) for i in str(n)]

M = []
a = 1

for i in range(len(L) - m + 1):
    a = L[i]*L[i + 1]*L[i + 2]*L[i + 3]*L[i + 4]*L[i + 5]*L[i + 6]*L[i + 7]*L[i + 8]*L[i + 9]*L[i + 10]*L[i + 11]*L[i + 12]
    M.append(a)

print(max(M))
print(len(L))
# Out:
# 23514624000
# 1000

# %%
# %%timeit
n = ...
m = 13

L = [int(i) for i in str(n)]

M = []
a = 1

for i in range(len(L) - m + 1):
    a = L[i]*L[i + 1]*L[i + 2]*L[i + 3]*L[i + 4]*L[i + 5]*L[i + 6]*L[i + 7]*L[i + 8]*L[i + 9]*L[i + 10]*L[i + 11]*L[i + 12]
    M.append(a)

#print(max(M))
#print(len(L))
# Out:
# 1.33 ms ± 26.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
